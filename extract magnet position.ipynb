# %%
import pandas as pd
import os.path
import re
#%pylab inline

# %%
path_all = "/Volumes/friebelm/PhD/NU Plasma/Measurements/2016-10-04/"
#path_all = "/Users/marf 1/Desktop/PhD Temp/2016-07-25/"

# %%
filenames = os.listdir(path_all)

# %%
#print filenames

# %%
blk_ls = []
sample_ls = []
std_ls = []
for i in filenames:
    sample = re.search(r""+"Results_"+"(.*).txt", i)
    if sample == None:
        None
    else:
        print sample.group(0)
# Out:
# Results_4973.txt
# Results_4972.txt
# Results_4971.txt
# Results_4970.txt
# Results_4969.txt
# Results_4968.txt
# Results_4967.txt
# Results_4966.txt
# Results_4965.txt
# Results_4964.txt
# Results_4963.txt
# Results_4962.txt
# Results_4961.txt
# Results_4960.txt
# Results_4959.txt
# Results_4958.txt
# Results_4957.txt
# Results_4956.txt
# Results_4955.txt
# Results_4954.txt
# Results_4953.txt
# Results_4952.txt
# Results_4951.txt
# Results_4950.txt
# Results_4949.txt
# Results_4948.txt
# Results_4947.txt
# Results_4946.txt
# Results_4945.txt
# Results_4944.txt
# Results_4943.txt
# Results_4942.txt
# Results_4941.txt
# Results_4940.txt
# Results_4939.txt
# Results_4938.txt
# Results_4937.txt
# Results_4936.txt
# Results_4935.txt
# Results_4934.txt
# Results_4933.txt
# Results_4932.txt
# Results_4931.txt
# Results_4930.txt
# Results_4929.txt
# Results_4928.txt
# Results_4927.txt
# Results_4926.txt
# Results_4925.txt
# Results_4924.txt
# Results_4923.txt
# Results_4922.txt
# Results_4921.txt
# Results_4920.txt
# Results_4974.txt
# Results_4978.txt
# Results_4977.txt
# Results_4976.txt
# Results_4975.txt
# Results_4987.txt
# Results_4980.txt
# Results_4984.txt
# Results_4983.txt
# Results_4982.txt
# Results_4981.txt
# Results_4979.txt
# Results_4985.txt
# Results_4986.txt
# Results_4991.txt
# Results_4990.txt
# Results_4989.txt
# Results_4988.txt

# %%
metadf = {}

# %%
metadata_group = ["Sample", "Date", "Analysis", "Axial"]
for i in filenames:
    sample = re.search(r""+"Results_"+"(.*).txt", i)
    if sample == None:
        None
    else:
        metadf[sample.group(1)] = []
        hand = open(path_all + sample.group(0))
        for line in hand:
            for metadata_string in metadata_group:
                if metadata_string in line:
                    metadata = re.search(r""+metadata_string+".*"+": (.*)\r", line)
                    if metadata != None:
                        metadf[sample.group(1)].append(metadata.group(1))
df = pd.DataFrame.from_dict(metadf, orient = 'index')
df.columns = ["Date", "Sample", "Analysis", "Axial"]
df.sort_index(by="Date")
# Out:
#                          Date                       Sample  \
# 4920  04 October 2016 (20:30)                    blank sol
# 4921  04 October 2016 (20:41)                  NIST 200ppb
# 4922  04 October 2016 (20:55)                    blank sol
# 4923  04 October 2016 (21:06)                  NIST 350ppb
# 4924  04 October 2016 (21:21)                    blank sol
# 4925  04 October 2016 (21:32)                  NIST 200ppb
# 4926  04 October 2016 (21:46)                  NIST 200ppb
# 4927  04 October 2016 (22:01)                  NIST 200ppb
# 4928  04 October 2016 (22:16)                  NIST 350ppb
# 4929  04 October 2016 (22:30)                  NIST 200ppb
# 4930  04 October 2016 (22:45)                    blank sol
# 4931  04 October 2016 (22:56)                  NIST 200ppb
# 4932  04 October 2016 (23:11)                  NIST 200ppb
# 4933  04 October 2016 (23:25)                  NIST 200ppb
# 4934  04 October 2016 (23:40)                  NIST 350ppb
# 4935  04 October 2016 (23:55)                  NIST 200ppb
# 4936  05 October 2016 (00:09)                    blank sol
# 4937  05 October 2016 (00:20)                  NIST 200ppb
# 4938  05 October 2016 (00:34)                  NIST 200ppb
# 4939  05 October 2016 (00:48)                  NIST 200ppb
# 4940  05 October 2016 (01:03)                  NIST 350ppb
# 4941  05 October 2016 (01:17)                  NIST 200ppb
# 4942  05 October 2016 (01:32)                    blank sol
# 4943  05 October 2016 (01:43)                  NIST 200ppb
# 4944  05 October 2016 (01:57)                  NIST 200ppb
# 4945  05 October 2016 (02:11)                  NIST 200ppb
# 4946  05 October 2016 (02:26)                  NIST 350ppb
# 4947  05 October 2016 (02:40)                  NIST 200ppb
# 4948  05 October 2016 (02:54)                    blank sol
# 4949  05 October 2016 (03:05)                  NIST 200ppb
# ...                       ...                          ...
# 4962  05 October 2016 (06:06)                  NIST 200ppb
# 4963  05 October 2016 (06:21)                  NIST 200ppb
# 4964  05 October 2016 (06:35)                  NIST 350ppb
# 4965  05 October 2016 (06:50)                  NIST 200ppb
# 4966  05 October 2016 (07:04)                    blank sol
# 4967  05 October 2016 (07:15)                  NIST 200ppb
# 4968  05 October 2016 (07:30)                  NIST 200ppb
# 4969  05 October 2016 (07:44)                  NIST 200ppb
# 4970  05 October 2016 (07:59)                  NIST 350ppb
# 4971  05 October 2016 (08:13)                  NIST 200ppb
# 4972  05 October 2016 (08:30)                    blank sol
# 4973  05 October 2016 (08:41)                  NIST 200ppb
# 4974  05 October 2016 (08:55)                  NIST 200ppb
# 4975  05 October 2016 (09:10)                  NIST 200ppb
# 4976  05 October 2016 (09:24)                  NIST 350ppb
# 4977  05 October 2016 (09:39)                  NIST 200ppb
# 4978  05 October 2016 (09:53)                    blank sol
# 4979  05 October 2016 (10:04)                  NIST 200ppb
# 4980  05 October 2016 (10:19)                  NIST 200ppb
# 4981  05 October 2016 (10:33)                  NIST 200ppb
# 4982  05 October 2016 (10:48)                  NIST 350ppb
# 4983  05 October 2016 (11:03)                  NIST 200ppb
# 4984  05 October 2016 (11:18)                    blank sol
# 4985  05 October 2016 (11:29)                  NIST 200ppb
# 4986  05 October 2016 (11:43)  ZH09-05 44.8_1_2 Sn TRU PRE
# 4987  05 October 2016 (11:58)                  NIST 200ppb
# 4988  05 October 2016 (12:13)      NIST 1000 ng Sn TRU PRE
# 4989  05 October 2016 (12:28)                  NIST 200ppb
# 4990  05 October 2016 (12:43)                    blank sol
# 4991  05 October 2016 (12:54)                  NIST 200ppb
#
#                                                Analysis               Axial
# 4920  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.631  122.545
# 4921  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.629  122.541
# 4922  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.626  122.541
# 4923  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.626  122.540
# 4924  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.626  122.540
# 4925  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.628  122.538
# 4926  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.626  122.538
# 4927  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.626  122.538
# 4928  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.626  122.539
# 4929  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.627  122.537
# 4930  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.623  122.537
# 4931  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.643  122.539
# 4932  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.625  122.537
# 4933  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.625  122.537
# 4934  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.625  122.535
# 4935  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.624  122.536
# 4936  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.622  122.536
# 4937  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.620  122.533
# 4938  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.622  122.535
# 4939  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.620  122.535
# 4940  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.624  122.537
# 4941  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.624  122.537
# 4942  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.623  122.537
# 4943  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.624  122.537
# 4944  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.624  122.536
# 4945  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.625  122.537
# 4946  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.622  122.535
# 4947  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.623  122.536
# 4948  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.622  122.536
# 4949  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.617  122.535
# ...                                                 ...                 ...
# 4962  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.623  122.535
# 4963  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.622  122.536
# 4964  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.626  122.536
# 4965  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.622  122.536
# 4966  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.622  122.536
# 4967  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.641  122.537
# 4968  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.625  122.537
# 4969  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.625  122.533
# 4970  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.621  122.536
# 4971  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.637  122.536
# 4972  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.622  122.536
# 4973  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.624  122.534
# 4974  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.616  122.534
# 4975  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.615  122.536
# 4976  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.624  122.533
# 4977  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.616  122.533
# 4978  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.620  122.533
# 4979  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.622  122.533
# 4980  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.615  122.535
# 4981  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.623  122.534
# 4982  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.624  122.536
# 4983  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.624  122.537
# 4984  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.623  122.537
# 4985  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.625  122.536
# 4986  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.624  122.537
# 4987  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.623  122.535
# 4988  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.623  122.537
# 4989  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.623  122.535
# 4990  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.621  122.535
# 4991  C:\Nu Plasma II\Analyses\Matthias\Sn_L4_H8_2cy...  115.623  122.535
#
# [72 rows x 4 columns]

# %%
df.to_csv(path_all + "magnet_position.csv", mode='w', header=True)
